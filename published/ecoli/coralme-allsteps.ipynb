# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from coralme.builder.main import MEBuilder

builder = MEBuilder(*['1.input+manual.json', '2.organism+manual.json'])
builder.configuration['run_bbh_blast'] = False
builder.generate_files(overwrite = True)
# builder.build_me_model(overwrite = False)
# builder.troubleshoot(growth_key_and_value = { builder.me_model.mu : 0.001 })
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-12
# /home/jt/UCSD/coralme/coralme/builder/main.py:30: UserWarning: This pandas version does not allow for correct warning handling. Pandas >=1.5.1 is suggested.
#   warnings.warn("This pandas version does not allow for correct warning handling. Pandas >=1.5.1 is suggested.")
# /home/jt/UCSD/coralme/coralme/builder/preprocess_inputs.py:15: UserWarning: This pandas version does not allow for correct warning handling. Pandas >=1.5.1 is suggested.
#   warnings.warn("This pandas version does not allow for correct warning handling. Pandas >=1.5.1 is suggested.")
# Initiating file processing...
# ~ Processing files for ecoli...
# Checking M-model metabolites...                                            : 100.0%|████████████████████████████████████████|  1660/ 1660 [00:00<00:00]
# ...

# %%
with open('trna_to_codon.txt', 'r') as infile:
    source = pandas.read_csv(infile, sep = '\t', header = None).set_index(0).to_dict()[1]
# source

with open('automated-org-with-refs.xlsx', 'rb') as infile:
    target = pandas.read_excel(infile)
target['tRNA-codon association'] = target.apply(lambda x: source.get(x['Gene Locus ID'], None), axis = 1)

import coralme
coralme.builder.preprocess_inputs._save_to_excel(target, 'automated-org-with-refs-tRNAs.xlsx')

# %%
builder.org.amino_acid_trna_synthetase
# Out:
# {'ala__L_c': 'Ala_RS_tetra_mod_zn2(4)',
#  'arg__L_c': 'ArgS_mono_mod_mg2(1)',
#  'asn__L_c': 'Asn_RS_dim',
#  'asp__L_c': 'Asp_RS_dim',
#  'cys__L_c': 'CysS_mono_mod_zn2(1)',
#  'gln__L_c': 'GlnS_mono',
#  'glu__L_c': 'GltX_mono_mod_mg2(1)_mod_zn2(1)',
#  'gly_c': 'Gly_RS_tetra',
#  'his__L_c': 'His_RS_dim_mod_mg2(4)',
#  'ile__L_c': 'IleS_mono_mod_zn2(2)',
#  'leu__L_c': 'LeuS_mono',
#  'lys__L_c': 'generic_lys_ligase',
#  'met__L_c': 'Met_RS_dim_mod_zn2(2)',
#  'phe__L_c': 'Phe_RS_tetra_mod_mg2(1)',
#  'pro__L_c': 'Pro_RS_dim',
#  'ser__L_c': 'Ser_RS_dim_mod_mg2(1)',
#  'thr__L_c': 'Thr_RS_dim_mod_zn2(1)',
#  'trp__L_c': 'Trp_RS_dim_mod_mg2(1)',
#  'tyr__L_c': 'Tyr_RS_dim',
#  'val__L_c': 'ValS_mono_mod_mg2(1)'}
